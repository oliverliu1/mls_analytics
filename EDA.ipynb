# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from pathlib import Path

# %%
Path.home()
# Out:
# WindowsPath('C:/Users/yenfu')

# %%
path = Path.home() / 'Downloads' / 'mls'
p = path.glob('**/*')
files = [x for x in p if x.is_file()]
files
# Out:
# [WindowsPath('C:/Users/yenfu/Downloads/mls/all_goalkeepers.csv'),
#  WindowsPath('C:/Users/yenfu/Downloads/mls/all_players.csv'),
#  WindowsPath('C:/Users/yenfu/Downloads/mls/all_tables.csv'),
#  WindowsPath('C:/Users/yenfu/Downloads/mls/events.csv'),
#  WindowsPath('C:/Users/yenfu/Downloads/mls/matches.csv')]

# %% [markdown]
# ## Questions and Ideas
#
# 1. Team performance comparison over the years
# 2. Players with most games/ minutes played
# 3. Relationship between every third of the field
# 4. Can we accurately predict match scores based on match stats?
# 5. Performance at home vs on the road
# 6. Fouls vs cards
# 7. Attributes of consistently high performing teams (e.g. early season performance)
# 8. Does high goal difference necessary imply good performance? and vice versa

# %% [markdown]
# ## Goalkeepers Table

# %%
file_path_gk = path / 'all_goalkeepers.csv'
df_goalkeepers = pd.read_csv(file_path_gk)

# %%
df_goalkeepers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2006 entries, 0 to 2005
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  2006 non-null   object
#  1   Club    1324 non-null   object
#  2   POS     2006 non-null   object
#  3   GP      2006 non-null   int64
#  4   GS      2006 non-null   int64
#  5   MINS    2006 non-null   int64
#  6   SHTS    2006 non-null   int64
#  7   SV      2006 non-null   int64
#  8   GA      2006 non-null   int64
#  9   GAA     2006 non-null   float64
#  10  PKG/A   2006 non-null   object
#  11  W       2006 non-null   int64
#  12  L       2006 non-null   int64
#  13  T       2006 non-null   int64
#  14  ShO     2006 non-null   int64
#  15  W%      2006 non-null   float64
#  16  Sv%     2006 non-null   float64
#  17  Year    2006 non-null   int64
#  18  Season  2006 non-null   object
# dtypes: float64(3), int64(11), object(5)
# memory usage: 297.9+ KB

# %%
df_goalkeepers.head(10)
# Out:
#            Player Club POS  GP  GS  MINS  SHTS   SV  GA   GAA PKG/A   W   L  \
# 0       Mark Dodd  DAL  GK  31  31  2776   235  160  45  1.45   5/5  17  14
# 1      Tony Meola  MET  GK  29  29  2610   188  142  38  1.31   3/4  14  15
# 2  Mark Dougherty  TB   GK  28  28  2520   186  123  47  1.68  9/10  17  11
# 3    Jorge Campos  LA   GK  24  24  2160   133  100  27  1.13   0/1  13   8
# 4  Garth Lagerwey  KC   GK  23  22  1959   133   83  38  1.73   2/2  12  10
# 5     Chris Woods  COL  GK  23  23  2070   149   96  43  1.87   2/2   8  15
# 6       Tom Liner  SJ   GK  20  20  1712   118   75  33  1.65   1/2   7  12
# 7    Aidan Heaney  NE   GK  19  18  1534   130   93  29  1.61   2/2   8   9
# 8     Jeff Causey  DC   GK  19  18  1620   115   70  35  1.94   7/8   9  10
# 9    David Kramer  LA   GK  15   8   855    83   52  22  2.75   4/4   6   5
#
#    T  ShO    W%   Sv%  Year Season
# 0  0    6  54.8  68.1  1996    reg
# 1  0    9  48.3  75.5  1996    reg
# ...

# %%
df_goalkeepers.query('Club=="TOR"')
# Out:
#                       Player Club POS  GP  GS  MINS  SHTS   SV  GA   GAA  \
# 440      Kenny Stamatopoulos  TOR  GK  12  12  1080    61   41  20  1.67
# 442        Srdjan Djekanovic  TOR  GK   8   7   635    34   22   9  1.29
# 443              Greg Sutton  TOR  GK   8   8   720    53   36  15  1.88
# 450             Sam Reynolds  TOR  GK   2   2   175    11    9   2  1.00
# 454           David Monsalve  TOR  GK   1   1    90    10    7   3  3.00
# 469         Tomer Chencinski  TOR  GK   0   0     0     0    0   0  0.00
# 480              Greg Sutton  TOR  GK  24  24  2160   160  116  35  1.46
# 491            Brian Edwards  TOR  GK   6   6   540    31   23   8  1.33
# 547            Brian Edwards  TOR  GK   3   3   270    17   11   6  2.00
# 548              Greg Sutton  TOR  GK   2   1   135     5    3   2  2.00
# 596              Milos Kocic  TOR  GK   2   1   107     8    5   3  3.00
# 599               Jon Conway  TOR  GK   1   1    72     2    2   1  1.00
# ...

# %% [markdown]
# ## Players Table

# %%
file_path_p = path / 'all_players.csv'
df_players = pd.read_csv(file_path_p)

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15767 entries, 0 to 15766
# Data columns (total 28 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   15767 non-null  object
#  1   Club     10274 non-null  object
#  2   POS      15767 non-null  object
#  3   GP       15767 non-null  int64
#  4   GS       15767 non-null  int64
#  5   MINS     15767 non-null  int64
#  6   G        15767 non-null  int64
#  7   A        15767 non-null  int64
#  8   SHTS     15767 non-null  int64
#  9   SOG      15767 non-null  int64
#  10  GWG      15767 non-null  int64
#  11  PKG/A    15767 non-null  object
#  12  HmG      15767 non-null  int64
#  13  RdG      15767 non-null  int64
#  14  G/90min  15767 non-null  float64
#  15  SC%      15767 non-null  float64
#  16  GWA      15767 non-null  int64
#  17  HmA      15767 non-null  int64
#  18  RdA      15767 non-null  int64
#  19  A/90min  15767 non-null  float64
#  20  FC       15767 non-null  int64
# ...

# %%
df_players.tail()
# Out:
#                   Player Club  POS  GP  GS  MINS  G  A  SHTS  SOG  ...  RdA  \
# 15762  Alejandro Pozuelo  NaN    M   1   1   120  0  0     5    0  ...    0
# 15763        Franco Jara  NaN    F   2   2   210  0  0     5    1  ...    0
# 15764          Andy Polo  NaN    M   1   1   105  0  0     6    3  ...    0
# 15765    Cristian Roldan  NaN    M   4   4   360  0  0     6    1  ...    0
# 15766       Joevin Jones  NaN  D-M   4   4   260  0  0     8    1  ...    0
#
#       A/90min  FC  FS  OFF  YC  RC   SOG%  Year  Season
# 15762     0.0   2   0    0   0   0   0.00  2020    post
# 15763     0.0   6   2    3   0   0  20.00  2020    post
# 15764     0.0   0   3    0   0   0  50.00  2020    post
# 15765     0.0   5  11    0   0   0  16.67  2020    post
# 15766     0.0   1   7    0   0   0  12.50  2020    post
#
# [5 rows x 28 columns]

# %%
df_players.query('Year==2020 & Season=="reg" & Club=="TOR" & POS=="F"')
# Out:
#                 Player Club POS  GP  GS  MINS  G  A  SHTS  SOG  ...  RdA  \
# 14619      Ayo Akinola  TOR   F  15  11  1063  9  0    36   18  ...    0
# 14764    Jozy Altidore  TOR   F  13  10   746  2  1    28   14  ...    0
# 14831  Patrick Mullins  TOR   F  16   4   416  1  1     8    4  ...    0
# 14861           Achara  TOR   F   1   1    89  1  0     2    2  ...    0
# 15224    Jayden Nelson  TOR   F   7   1   141  0  0     3    0  ...    0
#
#       A/90min  FC  FS  OFF  YC  RC   SOG%  Year  Season
# 14619    0.00  28   7   13   1   0   50.0  2020     reg
# 14764    0.12  12  12    5   3   0   50.0  2020     reg
# 14831    0.22   8   3    4   1   0   50.0  2020     reg
# 14861    0.00   1   1    1   0   0  100.0  2020     reg
# 15224    0.00   5   3    0   2   0    0.0  2020     reg
#
# [5 rows x 28 columns]

# %% [markdown]
# ## All Tables

# %%
file_path_all = path / 'all_tables.csv'
df_all_tables = pd.read_csv(file_path_all)

# %%
sorted(df_all_tables.Team.unique().tolist())
# Out:
# ['Atlanta United FC',
#  'Atlanta United FC (C)',
#  'Atlanta United FC (U)',
#  'Austin FC',
#  'CF Montréal',
#  'CF Montréal[a]',
#  'Chicago Fire',
#  'Chicago Fire (C1)',
#  'Chicago Fire (E3)',
#  'Chicago Fire FC',
#  'Chivas USA',
#  'Chivas USA (W1)',
#  'Colorado Rapids',
#  'Colorado Rapids (W3)',
#  'Columbus Crew',
#  'Columbus Crew (SS, E1)',
#  'Columbus Crew SC',
#  'Columbus Crew SC (C)',
#  'D.C. United',
#  'D.C. United (C)',
#  'D.C. United (C, X)',
#  'D.C. United (E1)',
#  'D.C. United (E2)',
#  'D.C. United (SS, E1)',
#  'D.C. United2',
#  'Dallas Burn',
#  'FC Cincinnati',
#  'FC Dallas',
#  'FC Dallas (W1)',
#  'FC Dallas (W2)',
#  'FC Dallas (X)',
#  'Houston Dynamo',
#  'Houston Dynamo (W1)',
#  'Houston Dynamo FC',
#  'Inter Miami CF',
#  'Kansas City Wiz',
#  'Kansas City Wizards',
#  'Kansas City Wizards (SS, W1)',
#  'LA Galaxy',
#  'LA Galaxy (SS, W1)',
#  'LA Galaxy (W1)',
#  'Los Angeles FC',
#  'Los Angeles FC (S)',
#  'Los Angeles Galaxy',
# ...

# %%
df_all_tables.query('Team=="Toronto FC"')
# Out:
#       Pos        Team  GP   W   L  SW  GF  GA   GD Pts  \
# 230   7.0  Toronto FC  30   9  13 NaN  34  43   –9  35
# 249  12.0  Toronto FC  30   9  13 NaN  34  43   −9  35
# 256   5.0  Toronto FC  30  10  11 NaN  37  46   −9  39
# 278  12.0  Toronto FC  30  10  11 NaN  37  46   −9  39
# 286   5.0  Toronto FC  30   9  13 NaN  33  41   −8  35
# 308  11.0  Toronto FC  30   9  13 NaN  33  41   −8  35
# 329  16.0  Toronto FC  34   6  13 NaN  36  59  −23  33
# 339   8.0  Toronto FC  34   6  13 NaN  36  59  −23  33
# 359  10.0  Toronto FC  34   5  21 NaN  36  62  −26  23
# 387  19.0  Toronto FC  34   5  21 NaN  36  62  −26  23
# 396   9.0  Toronto FC  34   6  17 NaN  30  47  −17  29
# 423  17.0  Toronto FC  34   6  17 NaN  30  47  −17  29
# 432   7.0  Toronto FC  34  11  15 NaN  44  54  −10  41
# 457  13.0  Toronto FC  34  11  15 NaN  44  54  −10  41
# 469   6.0  Toronto FC  34  15  15 NaN  58  58    0  49
# 495  12.0  Toronto FC  34  15  15 NaN  58  58    0  49
# ...
